# %% [markdown]
# ## Part C) lasso regression

# %%
import sys
import os
from matplotlib import pyplot as plt
sys.path.append(os.path.abspath('..'))
from part_c import *
from utils import *

# %%
mse_train, r2_train,mse_test,  r2_test,alphas,betas = lasso_on_ff_evaluation(num_alphas=6,scaling="standard",degrees=5)
# Out:
# [GENERATE FF DATA] xy shape: (400, 2)
# [GENERATE FF DATA] z shape: (400,)
# c:\Users\javid.rezai\AppData\Local\anaconda3\envs\p1\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.569e+00, tolerance: 3.200e-02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\javid.rezai\AppData\Local\anaconda3\envs\p1\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.216e+01, tolerance: 3.200e-02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
visualize_evaluation_metrics(mse_train, r2_train,mse_test, r2_test, alphas)

# %%
visualize_lasso_betas(betas, alphas)

# %%
visualize_lasso_beta_histogram(betas, alphas)

# %%
visualize_lasso_betas_norm(betas, alphas)
