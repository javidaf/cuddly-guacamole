# %% [markdown]
# ### Part a) OLS on Franke function
#
# Franke function is defined on the domain $x,y \in [0,1]$.
# 2D Franke function is defined as:
# $$
# f(x,y) = \frac{3}{4} \exp\left(-\frac{(9x-2)^2}{4} - \frac{(9y-2)^2}{4}\right) + \frac{3}{4} \exp\left(-\frac{(9x+1)^2}{49} - \frac{(9y+1)}{10}\right) + \frac{1}{2} \exp\left(-\frac{(9x-7)^2}{4} - \frac{(9y-3)^2}{4}\right) - \frac{1}{5} \exp\left(-(9x-4)^2 - (9y-7)^2\right)
# $$

# %% [markdown]
# ### OLS evaluation on Franke function
# **Scaling method**: standard

# %%
from part_a import *
import sys
import os
sys.path.append(os.path.abspath('..'))
ols_on_ff_evaluation(2,"none")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from part_a import *
#       2 import sys
#       3 import os
#
# ModuleNotFoundError: No module named 'part_a'

# %% [markdown]
# ### stadard scaling

# %%
ols_on_ff_evaluation(50,"standard")
# Out:
# [GENERATE FF DATA] xy shape: (20, 2)
# [GENERATE FF DATA] z shape: (20, 20)

# %%
ols_on_ff_evaluation(50,"power")
# Out:
# [GENERATE FF DATA] xy shape: (20, 2)
# [GENERATE FF DATA] z shape: (20, 20)

# %%
ols_on_ff_evaluation(50,"robust")
# Out:
# [GENERATE FF DATA] xy shape: (20, 2)
# [GENERATE FF DATA] z shape: (20, 20)

# %%
ols_on_ff_evaluation(50,"minmax")
# Out:
# [GENERATE FF DATA] xy shape: (20, 2)
# [GENERATE FF DATA] z shape: (20, 20)
