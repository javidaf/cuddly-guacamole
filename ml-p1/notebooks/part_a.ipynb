# %% [markdown]
# ## Part A) OLS on Franke Function

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from part_a import *

mse_train,r2_train, mse_test, r2_test, betas = ols_on_ff_evaluation(scaling="standard")
# Out:
# Running OLS on Franke's function up to degree 5.
# Scaling method: standard
# Adding noise: True
# Number of samples: 20
# Max degree 5: Train MSE=0.1351, Train R²=0.8649, Test MSE=0.2023, Test R²=0.8297

# %%
visualize_ols_metrics(mse_train, r2_train,mse_test, r2_test)

# %%
visualize_all_betas(betas)

# %%
visualize_betas_norm(betas)

# %%
visualize_beta_histogram(betas)
