# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from part_f import *

# %%
compare_CV_bootstrap(k=5)
# Out:
# [GENERATE FF DATA] xy shape: (400, 2)
# [GENERATE FF DATA] z shape: (400,)
# Running Bias-Variance Decomposition for OLS:
# [GENERATE FF DATA] xy shape: (400, 2)
# [GENERATE FF DATA] z shape: (400,)
# Degree 1: Bias^2 = 0.4499, Variance = 0.0030, MSE = 0.4530
# Degree 2: Bias^2 = 0.3734, Variance = 0.0053, MSE = 0.3788
# Degree 3: Bias^2 = 0.2363, Variance = 0.0062, MSE = 0.2426
# Degree 4: Bias^2 = 0.2111, Variance = 0.0085, MSE = 0.2196
# Degree 5: Bias^2 = 0.1928, Variance = 0.0113, MSE = 0.2041
#
# Running k-Fold Cross-Validation:
# Processing Fold 1/5
# Processing Fold 2/5
# Processing Fold 3/5
# Processing Fold 4/5
# Processing Fold 5/5
# OLS Regression: Average MSE = 0.3775 ± 0.1144
# Ridge Regression: Average MSE = 0.3775 ± 0.1147
# Lasso Regression: Average MSE = 0.3775 ± 0.1147
# Processing Fold 1/5
# Processing Fold 2/5
# Processing Fold 3/5
# Processing Fold 4/5
# Processing Fold 5/5
# OLS Regression: Average MSE = 0.3245 ± 0.0998
# ...

# %%
compare_CV_bootstrap(degree=10,k=5)
# Out:
# [GENERATE FF DATA] xy shape: (400, 2)
# [GENERATE FF DATA] z shape: (400,)
# Running Bias-Variance Decomposition for OLS:
# [GENERATE FF DATA] xy shape: (400, 2)
# [GENERATE FF DATA] z shape: (400,)
# Degree 1: Bias^2 = 0.3937, Variance = 0.0026, MSE = 0.3963
# Degree 2: Bias^2 = 0.3232, Variance = 0.0048, MSE = 0.3281
# Degree 3: Bias^2 = 0.1686, Variance = 0.0060, MSE = 0.1747
# Degree 4: Bias^2 = 0.1346, Variance = 0.0075, MSE = 0.1421
# Degree 5: Bias^2 = 0.1393, Variance = 0.0118, MSE = 0.1511
# Degree 6: Bias^2 = 0.1384, Variance = 0.0194, MSE = 0.1578
# Degree 7: Bias^2 = 0.1261, Variance = 0.0254, MSE = 0.1515
# Degree 8: Bias^2 = 0.1728, Variance = 0.0622, MSE = 0.2349
# Degree 9: Bias^2 = 0.1960, Variance = 0.0881, MSE = 0.2841
# Degree 10: Bias^2 = 0.2220, Variance = 0.1996, MSE = 0.4216
#
# Running k-Fold Cross-Validation:
# Processing Fold 1/5
# Processing Fold 2/5
# Processing Fold 3/5
# Processing Fold 4/5
# Processing Fold 5/5
# ...

# %%
compare_CV_bootstrap(degree=10)
# Out:
# [GENERATE FF DATA] xy shape: (400, 2)
# [GENERATE FF DATA] z shape: (400,)
# Running Bias-Variance Decomposition for OLS:
# [GENERATE FF DATA] xy shape: (400, 2)
# [GENERATE FF DATA] z shape: (400,)
# Degree 1: Bias^2 = 0.4177, Variance = 0.0032, MSE = 0.4209
# Degree 2: Bias^2 = 0.3551, Variance = 0.0061, MSE = 0.3612
# Degree 3: Bias^2 = 0.2218, Variance = 0.0075, MSE = 0.2293
# Degree 4: Bias^2 = 0.2095, Variance = 0.0095, MSE = 0.2190
# Degree 5: Bias^2 = 0.1946, Variance = 0.0122, MSE = 0.2068
# Degree 6: Bias^2 = 0.1686, Variance = 0.0166, MSE = 0.1852
# Degree 7: Bias^2 = 0.1416, Variance = 0.0247, MSE = 0.1663
# Degree 8: Bias^2 = 0.1361, Variance = 0.0421, MSE = 0.1783
# Degree 9: Bias^2 = 0.1579, Variance = 0.0944, MSE = 0.2523
# Degree 10: Bias^2 = 0.1759, Variance = 0.1982, MSE = 0.3740
#
# Running k-Fold Cross-Validation:
# Processing Fold 1/10
# Processing Fold 2/10
# Processing Fold 3/10
# Processing Fold 4/10
# Processing Fold 5/10
# Processing Fold 6/10
# ...

# %%
compare_CV_bootstrap(degree=10, k=10, n=40)
# Out:
# [GENERATE FF DATA] xy shape: (1600, 2)
# [GENERATE FF DATA] z shape: (1600,)
# Running Bias-Variance Decomposition for OLS:
# [GENERATE FF DATA] xy shape: (1600, 2)
# [GENERATE FF DATA] z shape: (1600,)
# Degree 1: Bias^2 = 0.3959, Variance = 0.0006, MSE = 0.3966
# Degree 2: Bias^2 = 0.3199, Variance = 0.0011, MSE = 0.3210
# Degree 3: Bias^2 = 0.2150, Variance = 0.0013, MSE = 0.2163
# Degree 4: Bias^2 = 0.1774, Variance = 0.0017, MSE = 0.1791
# Degree 5: Bias^2 = 0.1444, Variance = 0.0019, MSE = 0.1463
# Degree 6: Bias^2 = 0.1344, Variance = 0.0024, MSE = 0.1368
# Degree 7: Bias^2 = 0.1300, Variance = 0.0030, MSE = 0.1330
# Degree 8: Bias^2 = 0.1244, Variance = 0.0038, MSE = 0.1281
# Degree 9: Bias^2 = 0.1230, Variance = 0.0046, MSE = 0.1276
# Degree 10: Bias^2 = 0.1242, Variance = 0.0062, MSE = 0.1304
#
# Running k-Fold Cross-Validation:
# Processing Fold 1/10
# Processing Fold 2/10
# Processing Fold 3/10
# Processing Fold 4/10
# Processing Fold 5/10
# Processing Fold 6/10
# ...

# %%
compare_CV_bootstrap(degree=15, k=10, n=100)
# Out:
# [GENERATE FF DATA] xy shape: (10000, 2)
# [GENERATE FF DATA] z shape: (10000,)
# Running Bias-Variance Decomposition for OLS:
# [GENERATE FF DATA] xy shape: (10000, 2)
# [GENERATE FF DATA] z shape: (10000,)
# Degree 1: Bias^2 = 0.3829, Variance = 0.0001, MSE = 0.3830
# Degree 2: Bias^2 = 0.3021, Variance = 0.0002, MSE = 0.3022
# Degree 3: Bias^2 = 0.1941, Variance = 0.0002, MSE = 0.1944
# Degree 4: Bias^2 = 0.1550, Variance = 0.0003, MSE = 0.1553
# Degree 5: Bias^2 = 0.1372, Variance = 0.0004, MSE = 0.1375
# Degree 6: Bias^2 = 0.1278, Variance = 0.0004, MSE = 0.1282
# Degree 7: Bias^2 = 0.1182, Variance = 0.0005, MSE = 0.1188
# Degree 8: Bias^2 = 0.1168, Variance = 0.0007, MSE = 0.1175
# Degree 9: Bias^2 = 0.1162, Variance = 0.0008, MSE = 0.1170
# Degree 10: Bias^2 = 0.1145, Variance = 0.0010, MSE = 0.1154
# Degree 11: Bias^2 = 0.1138, Variance = 0.0010, MSE = 0.1148
# Degree 12: Bias^2 = 0.1143, Variance = 0.0012, MSE = 0.1154
# ...

# %%
compare_CV_bootstrap(degree=15, k=10, n=60,alphas={'ridge':1,'lasso':0.00158})
# Out:
# [GENERATE FF DATA] xy shape: (3600, 2)
# [GENERATE FF DATA] z shape: (3600,)
# Running Bias-Variance Decomposition for OLS:
# [GENERATE FF DATA] xy shape: (3600, 2)
# [GENERATE FF DATA] z shape: (3600,)
# Degree 1: Bias^2 = 0.3687, Variance = 0.0003, MSE = 0.3690
# Degree 2: Bias^2 = 0.2869, Variance = 0.0005, MSE = 0.2874
# Degree 3: Bias^2 = 0.1836, Variance = 0.0006, MSE = 0.1842
# Degree 4: Bias^2 = 0.1540, Variance = 0.0008, MSE = 0.1549
# Degree 5: Bias^2 = 0.1397, Variance = 0.0011, MSE = 0.1408
# Degree 6: Bias^2 = 0.1283, Variance = 0.0014, MSE = 0.1297
# Degree 7: Bias^2 = 0.1201, Variance = 0.0017, MSE = 0.1218
# Degree 8: Bias^2 = 0.1152, Variance = 0.0022, MSE = 0.1174
# Degree 9: Bias^2 = 0.1140, Variance = 0.0024, MSE = 0.1164
# Degree 10: Bias^2 = 0.1143, Variance = 0.0028, MSE = 0.1171
# Degree 11: Bias^2 = 0.1135, Variance = 0.0030, MSE = 0.1165
# Degree 12: Bias^2 = 0.1134, Variance = 0.0033, MSE = 0.1167
# ...
