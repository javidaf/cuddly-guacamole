# %% [markdown]
# ## Part B) Ridge on Franke Function

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from part_b import *
from utils import *

# %%
mse_train,r2_train, mse_test,  r2_test, alphas, betas = ridge_on_ff_evaluation(noise=False,
    num_alphas=6, scaling="standard"
)
visualize_evaluation_metrics(mse_train, r2_train, mse_test, r2_test, alphas)
# Out:
# [GENERATE FF DATA] xy shape: (400, 2)
# [GENERATE FF DATA] z shape: (400,)

# %%
visualize_betas_norm(betas, alphas)

# %%
from part_c import visualize_lasso_beta_histogram
visualize_lasso_beta_histogram(betas, alphas)
