# %% [markdown]
# # Part B) Ridge on Franke function

# %%
import sys
import os
from matplotlib import pyplot as plt
sys.path.append(os.path.abspath('..'))
from part_b import ridge_on_ff_evaluation, visualize_ridge_on_ff_evaluation,visualize_ridge_on_ff_betas

# %%
mse_train, r2_train, mse_test, r2_test, alphas, betas = ridge_on_ff_evaluation()
visualize_ridge_on_ff_evaluation(mse_train, r2_train, mse_test, r2_test, alphas)
# Out:
# [GENERATE FF DATA] xy shape: (20, 2)
# [GENERATE FF DATA] z shape: (20, 20)
# Degrees: 5

# %%
visualize_ridge_on_ff_betas(betas, alphas)

# %%
mse_train, r2_train, mse_test, r2_test, alphas, betas = ridge_on_ff_evaluation(scaling="robust",degrees=10)
visualize_ridge_on_ff_evaluation(mse_train, r2_train, mse_test, r2_test, alphas)
visualize_ridge_on_ff_betas(betas, alphas)
# Out:
# [GENERATE FF DATA] xy shape: (20, 2)
# [GENERATE FF DATA] z shape: (20, 20)
# Degrees: 10
